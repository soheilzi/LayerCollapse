# %%
import os
# !export CUDA_VISIBLE_DEVICES=1
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
# !pip3 install distiller

# %%
import torch
import distiller
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
import time
from torch.utils.data import DataLoader
from LiveTune import liveVar

# %%
# !pip3 freeze|grep Dis

# %%
# classes = ('plane', 'car', 'bird', 'cat',
#                'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

classes = [i for i in range(1000)]
# classes

# %%
def countParameters(net):
    params = 0
    for par in net.parameters():
        k = 1
        for x in par.size():
            k *= x
        params += k
    return params

def checkAccuracy(model, device, testloader):
    correct = 0
    total = 0
    model.eval()
    with torch.no_grad():
        for data in testloader:
            images, labels = data[0].to(device), data[1].to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = 100.0 * correct / total
    print('Accuracy of the network on the test images: %.2f %%' % (
        accuracy))
    model.train()
    return accuracy

# %%
def testModel(net, device, testloader):
    global classes
    correct = 0
    total = 0
    net.eval()
    print('Parameters:', countParameters(net))
    t1 = time.time()
    with torch.no_grad():
        for data in testloader:
            images, labels = data[0].to(device), data[1].to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
    t2 = time.time()
    print('Top-1 Accuracy of the network on the 10000 test images: %.2f %%' % (
        100 * correct / total))
    print('Average Latency for 10000 test images:', (t2-t1)/10000,'seconds')
    
#     class_correct = list(0. for i in range(1000))
#     class_total = list(0. for i in range(1000))
#     with torch.no_grad():
#         for data in testloader:
#             images, labels = data[0].to(device), data[1].to(device)
#             outputs = net(images)
#             _, predicted = torch.max(outputs, 1)
#             c = (predicted == labels).squeeze()
#             for i in range(len(labels)):
#                 label = labels[i]
#                 class_correct[label] += c[i].item()
#                 class_total[label] += 1
    
#     for i in range(1000):
#         print('Accuracy of %5s : %2f %%' % (
#             classes[i], 100.0 * class_correct[i] / class_total[i]))

# %%
def trainModel(net, modelLocation, device, trainloader, testloader, opt, startEpoch, totalEpochs, accuracy = 0):
    
    criterion = nn.CrossEntropyLoss()
    bestAccuracy = accuracy
    bestEpoch = startEpoch
    torch.save(net.state_dict(), modelLocation)
    if opt == optim.SGD:
        scheme = 1
    else:
        scheme = 0
    print(f"model has {get_num_parameters(model, True)/1e6:.2f} M parameters")
    for epoch in range(startEpoch, totalEpochs):  # loop over the dataset multiple times
        if scheme == 1:
            if epoch < 150:
                optimizer = opt(net.parameters(), lr=0.1, momentum = 0.9, weight_decay=5e-4)
            elif epoch < 250:
                optimizer = opt(net.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)
            else:
                optimizer = opt(net.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)
        else:
            optimizer = opt(net.parameters(), lr=0.001, weight_decay=5e-4)
        running_loss = 0.0
        
        for i, data in enumerate(trainloader, 0):
            # get the inputs
            inputs, labels = data[0].to(device), data[1].to(device)
    
            # zero the parameter gradients
            optimizer.zero_grad()
            # forward + backward + optimize
            # print("inputs.shape", inputs.shape)
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            # print statistics
            running_loss += loss.item()
            
            if i % 100 == 99:    # print every 128 mini-batches
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 100))
                running_loss = 0.0
        
        accuracy = checkAccuracy(net, device, testloader)
        if accuracy >= bestAccuracy:    
            torch.save(net.state_dict(), modelLocation)
            bestAccuracy = accuracy
            bestEpoch = epoch+1
        print('Best Accuracy of', bestAccuracy,'at epoch',bestEpoch)
        
    print('Finished Training Model.')
    try:
        net.load_state_dict(torch.load(modelLocation))
    except:
        pass
    
    testModel(net, device, testloader)

# %%
learning_rate = liveVar(0.0001, 'learning_rate')
# Out:
# Port number for liveVar dictionary: 44113

# %%
type(learning_rate())
# Out:
# float

# %%
def trainModelKD(model, modelLocation, teacher, device, trainloader, testloader, alpha, T, opt, startEpoch, totalEpochs, accuracy = 0):
#     global output
#     global labels
    criterion = nn.KLDivLoss(reduction="batchmean") # nn.CrossEntropyLoss()
    dlw = distiller.DistillationLossWeights(alpha*T*T, 1-alpha, 0.0)
    kd_policy = distiller.KnowledgeDistillationPolicy(model, teacher, T, dlw)
    kd_policy.active = True
    bestAccuracy = accuracy
    bestEpoch = startEpoch
    torch.save(model.state_dict(), modelLocation)
    if opt == optim.SGD:
        scheme = 1
    else:
        scheme = 0
    print(f"model has {get_num_parameters(model, True)/1e6:.2f} M parameters")
#     if scheme == 1:
#         if epoch < 150:
#             optimizer = opt(model.parameters(), lr=0.1, momentum = 0.9, weight_decay=5e-4)
#         elif epoch < 250:
#             optimizer = opt(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)
#         else:
#             optimizer = opt(model.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)
#     else:
#         optimizer = opt(model.parameters(), lr=0.001, weight_decay=5e-4)
    # optimizer = opt(model.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)
    # scheduler = lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, mode='min', verbose=True)
    for epoch in range(startEpoch, totalEpochs):  # loop over the dataset multiple times
        start = time.time()
        # for g in optim.param_groups:
        #     g['lr'] = learning_rate
        # optimizer = opt(model.parameters(), lr=learning_rate(), momentum=0.9, weight_decay=5e-4)
        optimizer = opt(model.parameters(), lr=learning_rate(), weight_decay=5e-4)
#         if scheme == 1:
#             if epoch < 150:
#                 optimizer = opt(model.parameters(), lr=0.1, momentum = 0.9, weight_decay=5e-4)
#             elif epoch < 250:
#                 optimizer = opt(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)
#             else:
#                 optimizer = opt(model.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)
#         else:
#             optimizer = opt(model.parameters(), lr=0.01, weight_decay=5e-4)
        running_loss = 0.0
#         scheduler = lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, mode='min', verbose=True)
        for i, data in enumerate(trainloader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            output = kd_policy.forward(inputs)
            np_labels = labels.cpu()
            one_hot_labels = np.eye(1000)[np_labels]
            one_hot_labels = torch.tensor(one_hot_labels).to(device)
            output_log = F.log_softmax(output)
            loss = criterion(output_log, one_hot_labels)
            loss = kd_policy.before_backward_pass(model, epoch, None, None, loss, None).overall_loss        
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            if i % 50 == 49:    # print every 2000 mini-batches
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 50))
                running_loss = 0.0
        accuracy = checkAccuracy(model, device, testloader)
        if accuracy > bestAccuracy:
            torch.save(model.state_dict(), modelLocation)
            bestAccuracy = accuracy
            bestEpoch = epoch+1
        print('Best Accuracy of', bestAccuracy,'at epoch',bestEpoch)
        # scheduler.step(accuracy)
        end = time.time()
        print("time taken:", end-start)
    
    print('Finished Training Student.')
    try:
        model.load_state_dict(torch.load(modelLocation))
    except:
        pass
    
    testModel(model, device, testloader)

# %%
import sys
# import resnet
import vgg
# import cnn5
import torch
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
# import train
# import avNet
# import netJoin
from utils import *

# %%
def get_platform():
    platforms = {
        'linux1' : 'Linux',
        'linux2' : 'Linux',
        'darwin' : 'OS X',
        'win32' : 'Windows'
    }
    if sys.platform not in platforms:
        return sys.platform
    
    return platforms[sys.platform]

# resDict = {'Resnet18': resnet.ResNet18, 
#                 'Resnet34': resnet.ResNet34,
#                 'Resnet50': resnet.ResNet50,
#                 'Resnet101': resnet.ResNet101,
#                 'Resnet152': resnet.ResNet152}


# models = ['Resnet18', 'Resnet34', 'Resnet50', 'Resnet101', 'Resnet152', 
#               'VGG6AS','VGG6AM','VGG6A','VGG6','VGG7','VGG8','VGG11','VGG13','VGG16','VGG16A','VGG19', '5-CNN']

models = ['VGG16']

def createResnet(ResType):
    global resDict    
    f = resDict[ResType]
    return f()

def createVGG(VGGType):
    return vgg.VGG(VGGType)

def create5_CNN():
    return cnn5.CNN_5()

def createNet(modelType):
    global models
    global jointModels
    
    for i in range(len(models)):
        if modelType.lower() == models[i].lower():
            if i <= 4:
                return createResnet(models[i])
            elif i <= len(models)-2:
                return createVGG(models[i])
            else:
                return create5_CNN()
    
    if modelType.lower() == 'avg':
        return avNet.AvNet()
    
    if modelType.lower() == 'jn':
        return netJoin.jointNet()
    
    return None

# %%
opt = optim.SGD
# elif sys.argv[4].lower() == 'sgd':
#     opt = optim.SGD
# else:
#     print('Invalid argument for specifying optimizer. Aborting.')
#     return

totalEpochs = 1000
startEpoch = 0
batchSize = 256

# %%
# def main():
    
global models

trainModel = trainModel
trainModelKD = trainModelKD
testModel = testModel

if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("CUDA Device Detected. GPU will be used.")
else:
    device = torch.device("cpu")
    print("No CUDA supported GPU detected. CPU will be used.")

print("Dataset- ImageNet")

if get_platform() == 'Windows':
    workers = 0
else:
    workers = 2

dataloader = get_dataloader("imagenet", batch_size=batchSize)
trainloader = dataloader['train']
testloader = dataloader['val']
#     transform = transforms.Compose(
#         [transforms.ToTensor(),
#          transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])
#     try:
#         testset = torchvision.datasets.CIFAR10(root=sys.argv[1], train=False,
#                                            download=False, transform=transform)
#     except:
#         testset = torchvision.datasets.CIFAR10(root=sys.argv[1], train=False,
#                                            download=True, transform=transform)
        
#     testloader = torch.utils.data.DataLoader(testset, batch_size=1024,
#                                              shuffle=False, num_workers=workers)
# Out:
# CUDA Device Detected. GPU will be used.
# Dataset- ImageNet

# %%
# opt = optim.SGD
# # elif sys.argv[4].lower() == 'sgd':
# #     opt = optim.SGD
# # else:
# #     print('Invalid argument for specifying optimizer. Aborting.')
# #     return

# totalEpochs = 1000
# startEpoch = 0
# batchSize = 256

# %%
import torchvision.models as models
base_model = models.vgg16(pretrained=True).cuda()
torch.save(base_model.state_dict(), "base_vgg16.pt")

# %%
@torch.inference_mode()
def evaluate_topk(
    model: nn.Module,
    dataloader: DataLoader, 
    verbose=True,
    device=None,
    topk = (1,)
) -> float:
  # model.eval()
    mega_list = []
    for inputs, targets in tqdm(dataloader, desc="eval", leave=False, 
                                disable=not verbose):
        # Move the data from CPU to GPU
        if device is None:
            inputs = inputs.cuda()
            targets = targets.cuda()
        else:
            inputs = inputs.to(device)
            targets = targets.to(device)

        # Inference
        outputs = model(inputs)
        maxk = max(topk)
        batch_size = targets.size(0)

        _, y_pred = outputs.topk(k=maxk, dim=1) 
        y_pred = y_pred.t()  

        target_reshaped = targets.view(1, -1).expand_as(y_pred)  
        correct = (y_pred == target_reshaped)  

        list_topk_accs = []  # idx is topk1, topk2, ... etc
        for k in topk:
            ind_which_topk_matched_truth = correct[:k]  # [maxk, B] -> [k, B]
            flattened_indicator_which_topk_matched_truth = ind_which_topk_matched_truth.reshape(-1).float()  # [k, B] -> [kB]
            tot_correct_topk = flattened_indicator_which_topk_matched_truth.float().sum(dim=0, keepdim=True)  # [kB] -> [1]
            topk_acc = tot_correct_topk / batch_size  # topk accuracy for entire batch
            list_topk_accs.append(topk_acc)
        mega_list.append(list_topk_accs)
    return mega_list  # list of topk accuracies for entire batch [topk1, topk2, ... etc]

# %%
mega_list = evaluate_topk(base_model, dataloader['val'], topk=(5,))

# %%
mega_list = [i[0].item() for i in mega_list]
print(sum(mega_list)/len(mega_list))
# Out:
# 0.8827665448188782

# %%
testModel(base_model, device, testloader)
# Out:
# Parameters: 138357544
# Top-1 Accuracy of the network on the 10000 test images: 71.22 %
# Average Latency for 10000 test images: 0.0007960352420806885 seconds

# %%
# elif sys.argv[8].lower() == 'n':

# model = createVGG('VGG16')
# if model is None:
#     print('Invalid Model Type. Aborting.')
# model = model.to(device)
# print(model)
# try:
#     model.load_state_dict(torch.load("base_vgg16_256_scratch.pt"))
#     accuracy = checkAccuracy(model, device, testloader)
#     print("accuracy:", accuracy)
# except Exception as e:
#     print(str(e))
#     accuracy = 0

# trainModel(model, "base_vgg16_256_scratch.pt", device, trainloader, testloader, opt, startEpoch, totalEpochs, accuracy)

# %%
# # if sys.argv[8].lower() == 'y': # Use distillation
# try:
alpha = 0.5
T = 2.0
# except:
#     print('Invalid Arguments for temperature or alpha. Aborting')
    # return
student_model = createVGG('VGG16')
print(student_model)
if student_model is None:
    print('Invalid Model Type. Aborting.')
    # return
student_model = student_model.to(device)    
try:
    student_model.load_state_dict(torch.load("student_vgg.pt"))
    accuracy = checkAccuracy(student_model, device, testloader)
except Exception as e:
    print("Exception loading student model:", str(e))
    accuracy = 0

teacher = base_model
if teacher is None:
    print('Invalid Model Type for Teacher. Aborting.')
    # return
teacher = teacher.to(device)
try:
    teacher.load_state_dict(torch.load("base_vgg16.pt"))
except Exception as e:
    print("Exception loading teacher model:", str(e))
    print('The Teacher model does not exists. Aborting.')
    # return
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (44): AdaptiveAvgPool2d(output_size=(7, 7))
#   )
#   (classifier): Sequential(
#     (0): Identity()
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Linear(in_features=25088, out_features=1000, bias=True)
#   )
# )
# Exception loading student model: [Errno 2] No such file or directory: 'student_vgg.pt'

# %%
# student_model.features[0].weight = teacher.features[0].weight
# student_model.features[0].bias = teacher.features[0].bias
# student_model.features[3].weight = teacher.features[2].weight
# student_model.features[3].bias = teacher.features[2].bias
# student_model.features[7].weight = teacher.features[5].weight
# student_model.features[7].bias = teacher.features[5].bias
# student_model.features[10].weight = teacher.features[7].weight
# student_model.features[10].bias = teacher.features[7].bias
# student_model.features[14].weight = teacher.features[10].weight
# student_model.features[14].bias = teacher.features[10].bias
# student_model.features[17].weight = teacher.features[12].weight
# student_model.features[17].bias = teacher.features[12].bias
# student_model.features[20].weight = teacher.features[14].weight
# student_model.features[20].bias = teacher.features[14].bias
# student_model.features[24].weight = teacher.features[17].weight
# student_model.features[24].bias = teacher.features[17].bias
# student_model.features[27].weight = teacher.features[19].weight
# student_model.features[27].bias = teacher.features[19].bias
# student_model.features[30].weight = teacher.features[21].weight
# student_model.features[30].bias = teacher.features[21].bias
# student_model.features[34].weight = teacher.features[24].weight
# student_model.features[34].bias = teacher.features[24].bias
# student_model.features[37].weight = teacher.features[26].weight
# student_model.features[37].bias = teacher.features[26].bias
# student_model.features[40].weight = teacher.features[28].weight
# student_model.features[40].bias = teacher.features[28].bias

# %%
# student_model.classifier[6]

# %%
for param in teacher.parameters():
    param.requires_grad = False
teacher.eval()
trainModelKD(student_model, "student_vgg.pt", teacher, device, trainloader, testloader, alpha, T, opt, startEpoch, totalEpochs, accuracy)
# return
# Out:
# model has 39.81 M parameters
# [1,    50] loss: 50.004
# [1,   100] loss: 37.365
# [1,   150] loss: 35.871
# [1,   200] loss: 35.684
# [1,   250] loss: 35.204
# [1,   350] loss: 34.607
# [1,   400] loss: 34.361
# [1,   450] loss: 33.546
# [1,   500] loss: 33.666
# Accuracy of the network on the test images: 0.76 %
# Best Accuracy of 0.76 at epoch 1
# time taken: 673.0109901428223
# [2,    50] loss: 34.235
# [2,   100] loss: 33.677
# [2,   150] loss: 33.045
# [2,   200] loss: 32.949
# [2,   250] loss: 32.842
# [2,   300] loss: 32.657
# [2,   350] loss: 32.048
# [2,   400] loss: 31.048
# [2,   450] loss: 30.481
# [2,   500] loss: 30.416
# Accuracy of the network on the test images: 3.18 %
# Best Accuracy of 3.18 at epoch 2
# time taken: 670.6775522232056
# [3,    50] loss: 29.827
# [3,   100] loss: 29.792
# [3,   150] loss: 29.503
# [3,   200] loss: 28.489
# [3,   250] loss: 28.211
# [3,   300] loss: 28.116
# [3,   350] loss: 27.497
# [3,   400] loss: 27.211
# [3,   450] loss: 26.923
# [3,   500] loss: 27.248
# Accuracy of the network on the test images: 5.04 %
# Best Accuracy of 5.04 at epoch 3
# time taken: 670.6889350414276
# [4,    50] loss: 26.787
# [4,   100] loss: 26.324
# [4,   150] loss: 25.816
# [4,   200] loss: 25.105
# [4,   250] loss: 25.103
# [4,   300] loss: 24.663
# [4,   350] loss: 24.491
# [4,   400] loss: 24.379
# [4,   450] loss: 24.104
# [4,   500] loss: 24.011
# Accuracy of the network on the test images: 10.32 %
# Best Accuracy of 10.32 at epoch 4
# time taken: 670.6846885681152
# [5,    50] loss: 23.988
# [5,   100] loss: 23.397
# [5,   150] loss: 23.217
# [5,   200] loss: 23.149
# [5,   250] loss: 22.543
# [5,   300] loss: 22.475
# [5,   350] loss: 22.242
# [5,   400] loss: 22.002
# [5,   450] loss: 21.746
# [5,   500] loss: 21.666
# Accuracy of the network on the test images: 13.78 %
# Best Accuracy of 13.78 at epoch 5
# time taken: 670.7497591972351
# [6,    50] loss: 21.744
# [6,   100] loss: 21.013
# [6,   150] loss: 20.474
# [6,   200] loss: 20.568
# [6,   250] loss: 20.428
# [6,   300] loss: 20.178
# [6,   350] loss: 20.258
# [6,   400] loss: 19.869
# [6,   450] loss: 19.841
# [6,   500] loss: 19.727
# Accuracy of the network on the test images: 16.10 %
# Best Accuracy of 16.1 at epoch 6
# time taken: 670.384443283081
# [7,    50] loss: 19.357
# [7,   100] loss: 18.923
# [7,   150] loss: 18.796
# [7,   200] loss: 18.744
# [7,   250] loss: 18.734
# [7,   300] loss: 18.382
# [7,   350] loss: 18.388
# [7,   400] loss: 18.235
# [7,   450] loss: 18.095
# [7,   500] loss: 18.161
# Accuracy of the network on the test images: 18.52 %
# Best Accuracy of 18.52 at epoch 7
# time taken: 670.4449598789215
# [8,    50] loss: 17.606
# [8,   100] loss: 17.268
# [8,   150] loss: 17.064
# [8,   200] loss: 17.379
# [8,   250] loss: 17.169
# [8,   300] loss: 17.091
# [8,   350] loss: 16.932
# [8,   400] loss: 16.719
# [8,   450] loss: 16.536
# [8,   500] loss: 16.662
# Accuracy of the network on the test images: 21.56 %
# Best Accuracy of 21.56 at epoch 8
# time taken: 670.1366052627563
# [9,    50] loss: 16.179
# [9,   100] loss: 15.761
# [9,   150] loss: 15.699
# [9,   200] loss: 15.797
# [9,   250] loss: 15.778
# [9,   300] loss: 15.587
# [9,   350] loss: 15.695
# [9,   400] loss: 15.629
# [9,   450] loss: 15.583
# [9,   500] loss: 15.568
# Accuracy of the network on the test images: 23.36 %
# Best Accuracy of 23.36 at epoch 9
# time taken: 670.0395293235779
# [10,    50] loss: 15.011
# [10,   100] loss: 14.673
# [10,   150] loss: 14.588
# [10,   200] loss: 14.707
# [10,   250] loss: 14.536
# [10,   300] loss: 14.567
# [10,   350] loss: 14.706
# [10,   400] loss: 14.552
# [10,   450] loss: 14.493
# [10,   500] loss: 14.404
# Accuracy of the network on the test images: 25.84 %
# Best Accuracy of 25.84 at epoch 10
# time taken: 669.7049641609192
# [11,    50] loss: 13.918
# [11,   100] loss: 13.736
# [11,   150] loss: 13.732
# [11,   200] loss: 13.643
# [11,   250] loss: 13.642
# [11,   300] loss: 13.815
# [11,   350] loss: 13.662
# [11,   400] loss: 13.606
# [11,   450] loss: 13.633
# [11,   500] loss: 13.558
# Accuracy of the network on the test images: 22.62 %
# Best Accuracy of 25.84 at epoch 10
# time taken: 669.6157352924347
# [12,    50] loss: 13.021
# [12,   100] loss: 12.821
# [12,   150] loss: 12.817
# [12,   200] loss: 12.954
# [12,   250] loss: 12.921
# [12,   300] loss: 12.770
# [12,   350] loss: 12.913
# [12,   400] loss: 12.969
# [12,   450] loss: 12.943
# [12,   500] loss: 12.861
# Accuracy of the network on the test images: 28.16 %
# Best Accuracy of 28.16 at epoch 12
# time taken: 669.3983769416809
# [13,    50] loss: 12.199
# [13,   100] loss: 12.186
# [13,   150] loss: 12.165
# [13,   200] loss: 12.300
# [13,   250] loss: 12.393
# [13,   300] loss: 12.264
# [13,   350] loss: 12.395
# [13,   400] loss: 12.215
# [13,   450] loss: 12.336
# [13,   500] loss: 12.245
# Accuracy of the network on the test images: 28.80 %
# Best Accuracy of 28.8 at epoch 13
# time taken: 669.8169958591461
# [14,    50] loss: 11.706
# [14,   100] loss: 11.427
# [14,   150] loss: 11.512
# [14,   200] loss: 11.609
# [14,   250] loss: 11.725
# [14,   300] loss: 11.882
# [14,   350] loss: 11.722
# [14,   400] loss: 11.764
# [14,   450] loss: 11.813
# [14,   500] loss: 11.758
# Accuracy of the network on the test images: 30.68 %
# Best Accuracy of 30.68 at epoch 14
# time taken: 669.7763466835022
# [15,    50] loss: 11.154
# [15,   100] loss: 10.963
# [15,   150] loss: 10.958
# [15,   200] loss: 11.148
# [15,   250] loss: 11.263
# [15,   300] loss: 11.175
# [15,   350] loss: 11.274
# [15,   400] loss: 11.356
# [15,   450] loss: 11.364
# [15,   500] loss: 11.156
# Accuracy of the network on the test images: 31.34 %
# Best Accuracy of 31.34 at epoch 15
# time taken: 669.6856842041016
# [16,    50] loss: 10.613
# [16,   100] loss: 10.584
# [16,   150] loss: 10.718
# [16,   200] loss: 10.715
# [16,   250] loss: 10.800
# [16,   300] loss: 10.687
# [16,   350] loss: 10.852
# [16,   400] loss: 10.838
# [16,   450] loss: 10.809
# [16,   500] loss: 10.949
# Accuracy of the network on the test images: 33.54 %
# Best Accuracy of 33.54 at epoch 16
# time taken: 669.5353364944458
# [17,    50] loss: 10.240
# [17,   100] loss: 10.086
# [17,   150] loss: 10.218
# [17,   200] loss: 10.317
# [17,   250] loss: 10.417
# [17,   300] loss: 10.391
# [17,   350] loss: 10.363
# [17,   400] loss: 10.359
# [17,   450] loss: 10.486
# [17,   500] loss: 10.611
# Accuracy of the network on the test images: 32.60 %
# Best Accuracy of 33.54 at epoch 16
# time taken: 669.1167829036713
# [18,    50] loss: 9.836
# [18,   100] loss: 9.758
# [18,   150] loss: 9.813
# [18,   200] loss: 9.968
# [18,   250] loss: 9.972
# [18,   300] loss: 9.944
# [18,   350] loss: 10.132
# [18,   400] loss: 10.084
# [18,   450] loss: 10.180
# [18,   500] loss: 10.109
# Accuracy of the network on the test images: 33.36 %
# Best Accuracy of 33.54 at epoch 16
# time taken: 669.2598948478699
# [19,    50] loss: 9.552
# [19,   100] loss: 9.429
# [19,   150] loss: 9.533
# [19,   200] loss: 9.541
# [19,   250] loss: 9.674
# [19,   300] loss: 9.921
# [19,   350] loss: 9.917
# [19,   400] loss: 9.812
# [19,   450] loss: 9.772
# [19,   500] loss: 9.837
# Accuracy of the network on the test images: 33.84 %
# Best Accuracy of 33.84 at epoch 19
# time taken: 669.8044090270996
# [20,    50] loss: 9.314
# [20,   100] loss: 9.148
# [20,   150] loss: 9.125
# [20,   200] loss: 9.295
# [20,   250] loss: 9.417
# [20,   300] loss: 9.438
# [20,   350] loss: 9.432
# [20,   400] loss: 9.431
# [20,   450] loss: 9.513
# [20,   500] loss: 9.688
# Accuracy of the network on the test images: 33.38 %
# Best Accuracy of 33.84 at epoch 19
# time taken: 669.7512094974518
# [21,    50] loss: 8.974
# [21,   100] loss: 8.890
# [21,   150] loss: 8.991
# [21,   200] loss: 9.099
# [21,   250] loss: 9.142
# [21,   300] loss: 9.155
# [21,   350] loss: 9.253
# [21,   400] loss: 9.201
# [21,   450] loss: 9.220
# [21,   500] loss: 9.418
# Accuracy of the network on the test images: 33.48 %
# Best Accuracy of 33.84 at epoch 19
# time taken: 669.8071060180664
# [22,    50] loss: 8.664
# [22,   100] loss: 8.677
# [22,   150] loss: 8.752
# [22,   200] loss: 8.752
# [22,   250] loss: 9.020
# [22,   300] loss: 9.020
# [22,   350] loss: 9.026
# [22,   400] loss: 9.006
# [22,   450] loss: 9.099
# [22,   500] loss: 9.107
# Accuracy of the network on the test images: 36.14 %
# Best Accuracy of 36.14 at epoch 22
# time taken: 669.6956973075867
# [23,    50] loss: 8.522
# [23,   100] loss: 8.409
# [23,   150] loss: 8.625
# [23,   200] loss: 8.614
# [23,   250] loss: 8.599
# [23,   300] loss: 8.781
# [23,   350] loss: 8.870
# [23,   400] loss: 8.781
# [23,   450] loss: 8.984
# [23,   500] loss: 8.926
# Accuracy of the network on the test images: 35.78 %
# Best Accuracy of 36.14 at epoch 22
# time taken: 669.4145662784576
# [24,    50] loss: 8.457
# [24,   100] loss: 8.245
# [24,   150] loss: 8.380
# [24,   200] loss: 8.394
# [24,   250] loss: 8.491
# [24,   300] loss: 8.603
# [24,   350] loss: 8.622
# [24,   400] loss: 8.648
# [24,   450] loss: 8.743
# [24,   500] loss: 8.798
# Accuracy of the network on the test images: 38.30 %
# Best Accuracy of 38.3 at epoch 24
# time taken: 669.8095555305481
# [25,    50] loss: 8.186
# [25,   100] loss: 8.089
# [25,   150] loss: 8.102
# [25,   200] loss: 8.295
# [25,   250] loss: 8.470
# [25,   300] loss: 8.370
# [25,   350] loss: 8.483
# [25,   400] loss: 8.550
# [25,   450] loss: 8.473
# [25,   500] loss: 8.610
# Accuracy of the network on the test images: 37.52 %
# Best Accuracy of 38.3 at epoch 24
# time taken: 669.1401581764221
# [26,    50] loss: 8.041
# [26,   100] loss: 7.950
# [26,   150] loss: 8.085
# [26,   200] loss: 8.097
# [26,   250] loss: 8.244
# [26,   300] loss: 8.238
# [26,   350] loss: 8.384
# [26,   400] loss: 8.367
# [26,   450] loss: 8.413
# [26,   500] loss: 8.409
# Accuracy of the network on the test images: 39.08 %
# Best Accuracy of 39.08 at epoch 26
# time taken: 669.5664989948273
# [27,    50] loss: 8.006
# [27,   100] loss: 7.802
# [27,   150] loss: 7.841
# [27,   200] loss: 7.966
# [27,   250] loss: 8.124
# [27,   300] loss: 8.145
# [27,   350] loss: 8.221
# [27,   400] loss: 8.116
# [27,   450] loss: 8.209
# [27,   500] loss: 8.295
# Accuracy of the network on the test images: 38.04 %
# Best Accuracy of 39.08 at epoch 26
# time taken: 669.5618138313293
# [28,    50] loss: 7.789
# [28,   100] loss: 7.557
# [28,   150] loss: 7.841
# [28,   200] loss: 7.859
# [28,   250] loss: 7.906
# [28,   300] loss: 8.019
# [28,   350] loss: 8.113
# [28,   400] loss: 8.084
# [28,   450] loss: 8.227
# [28,   500] loss: 8.173
# Accuracy of the network on the test images: 38.68 %
# Best Accuracy of 39.08 at epoch 26
# time taken: 669.3569643497467
# [29,    50] loss: 7.677
# [29,   100] loss: 7.553
# [29,   150] loss: 7.602
# [29,   200] loss: 7.757
# [29,   250] loss: 7.822
# [29,   300] loss: 7.916
# [29,   350] loss: 7.997
# [29,   400] loss: 7.974
# [29,   450] loss: 8.029
# [29,   500] loss: 8.013
# Accuracy of the network on the test images: 38.62 %
# Best Accuracy of 39.08 at epoch 26
# time taken: 669.3451154232025
# [30,    50] loss: 7.576
# [30,   100] loss: 7.387
# [30,   150] loss: 7.512
# [30,   200] loss: 7.707
# [30,   250] loss: 7.709
# [30,   300] loss: 7.862
# [30,   350] loss: 7.912
# [30,   400] loss: 7.780
# [30,   450] loss: 7.831
# [30,   500] loss: 7.855
# Accuracy of the network on the test images: 39.58 %
# Best Accuracy of 39.58 at epoch 30
# time taken: 666.4222004413605
# [31,    50] loss: 7.447
# [31,   100] loss: 7.217
# [31,   150] loss: 7.452
# [31,   200] loss: 7.669
# [31,   250] loss: 7.613
# [31,   300] loss: 7.700
# [31,   350] loss: 7.733
# [31,   400] loss: 7.868
# [31,   450] loss: 7.812
# [31,   500] loss: 7.855
# Accuracy of the network on the test images: 39.76 %
# Best Accuracy of 39.76 at epoch 31
# time taken: 665.9016869068146
# [32,    50] loss: 7.363
# [32,   100] loss: 7.237
# [32,   150] loss: 7.330
# [32,   200] loss: 7.518
# [32,   250] loss: 7.566
# [32,   300] loss: 7.660
# [32,   350] loss: 7.677
# [32,   400] loss: 7.731
# [32,   450] loss: 7.734
# [32,   500] loss: 7.913
# Accuracy of the network on the test images: 39.14 %
# Best Accuracy of 39.76 at epoch 31
# time taken: 665.0216627120972
# [33,    50] loss: 7.291
# [33,   100] loss: 7.153
# [33,   150] loss: 7.313
# [33,   200] loss: 7.370
# [33,   250] loss: 7.462
# [33,   300] loss: 7.582
# [33,   350] loss: 7.553
# [33,   400] loss: 7.609
# [33,   450] loss: 7.739
# [33,   500] loss: 7.599
# Accuracy of the network on the test images: 39.76 %
# Best Accuracy of 39.76 at epoch 31
# time taken: 664.9161829948425
# [34,    50] loss: 7.150
# [34,   100] loss: 7.065
# [34,   150] loss: 7.282
# [34,   200] loss: 7.197
# [34,   250] loss: 7.457
# [34,   300] loss: 7.431
# [34,   350] loss: 7.435
# [34,   400] loss: 7.404
# [34,   450] loss: 7.471
# [34,   500] loss: 7.669
# Accuracy of the network on the test images: 40.64 %
# Best Accuracy of 40.64 at epoch 34
# time taken: 665.1595604419708
# [35,    50] loss: 7.141
# [35,   100] loss: 7.019
# [35,   150] loss: 7.108
# [35,   200] loss: 7.213
# [35,   250] loss: 7.243
# [35,   300] loss: 7.370
# [35,   350] loss: 7.480
# [35,   400] loss: 7.396
# [35,   450] loss: 7.487
# [35,   500] loss: 7.581
# Accuracy of the network on the test images: 38.68 %
# Best Accuracy of 40.64 at epoch 34
# time taken: 664.6342399120331
# [36,    50] loss: 7.019
# [36,   100] loss: 6.923
# [36,   150] loss: 6.956
# [36,   200] loss: 7.073
# [36,   250] loss: 7.250
# [36,   300] loss: 7.303
# [36,   350] loss: 7.325
# [36,   400] loss: 7.423
# [36,   450] loss: 7.579
# [36,   500] loss: 7.527
# Accuracy of the network on the test images: 41.22 %
# Best Accuracy of 41.22 at epoch 36
# time taken: 664.9314181804657
# [37,    50] loss: 6.922
# [37,   100] loss: 6.853
# [37,   150] loss: 7.038
# [37,   200] loss: 7.114
# [37,   250] loss: 7.288
# [37,   300] loss: 7.231
# [37,   350] loss: 7.223
# [37,   400] loss: 7.336
# [37,   450] loss: 7.321
# [37,   500] loss: 7.307
# Accuracy of the network on the test images: 40.54 %
# Best Accuracy of 41.22 at epoch 36
# time taken: 664.7562396526337
# [38,    50] loss: 6.877
# [38,   100] loss: 6.800
# [38,   150] loss: 6.981
# [38,   200] loss: 7.085
# [38,   250] loss: 7.090
# [38,   300] loss: 7.288
# [38,   350] loss: 7.242
# [38,   400] loss: 7.250
# [38,   450] loss: 7.345
# [38,   500] loss: 7.260
# Accuracy of the network on the test images: 38.88 %
# Best Accuracy of 41.22 at epoch 36
# time taken: 664.4494740962982
# [39,    50] loss: 6.821
# [39,   100] loss: 6.706
# [39,   150] loss: 6.926
# [39,   200] loss: 6.950
# [39,   250] loss: 7.049
# [39,   300] loss: 7.094
# [39,   350] loss: 7.136
# [39,   400] loss: 7.203
# [39,   450] loss: 7.282
# [39,   500] loss: 7.319
# Accuracy of the network on the test images: 41.36 %
# Best Accuracy of 41.36 at epoch 39
# time taken: 664.6731081008911
# [40,    50] loss: 6.802
# [40,   100] loss: 6.705
# [40,   150] loss: 6.791
# [40,   200] loss: 6.841
# [40,   250] loss: 7.083
# [40,   300] loss: 7.076
# [40,   350] loss: 7.141
# [40,   400] loss: 7.231
# [40,   450] loss: 7.147
# [40,   500] loss: 7.241
# Accuracy of the network on the test images: 41.04 %
# Best Accuracy of 41.36 at epoch 39
# time taken: 664.4643650054932
# [41,    50] loss: 6.721
# [41,   100] loss: 6.624
# [41,   150] loss: 6.731
# [41,   200] loss: 6.946
# [41,   250] loss: 6.921
# [41,   300] loss: 7.105
# [41,   350] loss: 7.018
# [41,   400] loss: 7.067
# [41,   450] loss: 7.225
# [41,   500] loss: 7.215
# Accuracy of the network on the test images: 41.68 %
# Best Accuracy of 41.68 at epoch 41
# time taken: 664.7024540901184
# [42,    50] loss: 6.678
# [42,   100] loss: 6.561
# [42,   150] loss: 6.703
# [42,   200] loss: 6.724
# [42,   250] loss: 6.863
# [42,   300] loss: 7.004
# [42,   350] loss: 7.111
# [42,   400] loss: 7.126
# [42,   450] loss: 7.132
# [42,   500] loss: 7.090
# Accuracy of the network on the test images: 40.86 %
# Best Accuracy of 41.68 at epoch 41
# time taken: 664.624440908432
# [43,    50] loss: 6.604
# [43,   100] loss: 6.492
# [43,   150] loss: 6.665
# [43,   200] loss: 6.791
# [43,   250] loss: 6.873
# [43,   300] loss: 6.923
# [43,   350] loss: 7.010
# [43,   400] loss: 6.997
# [43,   450] loss: 7.108
# [43,   500] loss: 7.111
# Accuracy of the network on the test images: 41.34 %
# Best Accuracy of 41.68 at epoch 41
# time taken: 664.1839997768402
# [44,    50] loss: 6.530
# [44,   100] loss: 6.502
# [44,   150] loss: 6.645
# [44,   200] loss: 6.810
# [44,   250] loss: 6.841
# [44,   300] loss: 6.860
# [44,   350] loss: 6.886
# [44,   400] loss: 7.024
# [44,   450] loss: 7.026
# [44,   500] loss: 7.015
# Accuracy of the network on the test images: 41.78 %
# Best Accuracy of 41.78 at epoch 44
# time taken: 664.6536707878113
# [45,    50] loss: 6.645
# [45,   100] loss: 6.453
# [45,   150] loss: 6.685
# [45,   200] loss: 6.701
# [45,   250] loss: 6.671
# [45,   300] loss: 6.895
# [45,   350] loss: 6.868
# [45,   400] loss: 6.882
# [45,   450] loss: 6.973
# [45,   500] loss: 7.013
# Accuracy of the network on the test images: 41.98 %
# Best Accuracy of 41.98 at epoch 45
# time taken: 664.7948250770569
# [46,    50] loss: 6.504
# [46,   100] loss: 6.510
# [46,   150] loss: 6.541
# [46,   200] loss: 6.668
# [46,   250] loss: 6.831
# [46,   300] loss: 6.734
# [46,   350] loss: 6.914
# [46,   400] loss: 6.912
# [46,   450] loss: 6.991
# [46,   500] loss: 6.989
# Accuracy of the network on the test images: 43.22 %
# Best Accuracy of 43.22 at epoch 46
# time taken: 664.5983347892761
# [47,    50] loss: 6.525
# [47,   100] loss: 6.406
# [47,   150] loss: 6.497
# [47,   200] loss: 6.609
# [47,   250] loss: 6.694
# [47,   300] loss: 6.738
# [47,   350] loss: 6.828
# [47,   400] loss: 6.848
# [47,   450] loss: 6.888
# [47,   500] loss: 7.051
# Accuracy of the network on the test images: 42.86 %
# Best Accuracy of 43.22 at epoch 46
# time taken: 664.4743039608002
# [48,    50] loss: 6.465
# [48,   100] loss: 6.360
# [48,   150] loss: 6.470
# [48,   200] loss: 6.672
# [48,   250] loss: 6.658
# [48,   300] loss: 6.704
# [48,   350] loss: 6.790
# [48,   400] loss: 6.853
# [48,   450] loss: 6.800
# [48,   500] loss: 7.025
# Accuracy of the network on the test images: 42.94 %
# Best Accuracy of 43.22 at epoch 46
# time taken: 664.1481900215149
# [49,    50] loss: 6.560
# [49,   100] loss: 6.224
# [49,   150] loss: 6.433
# [49,   200] loss: 6.550
# [49,   250] loss: 6.511
# [49,   300] loss: 6.796
# [49,   350] loss: 6.806
# [49,   400] loss: 6.858
# [49,   450] loss: 6.815
# [49,   500] loss: 6.844
# Accuracy of the network on the test images: 43.02 %
# Best Accuracy of 43.22 at epoch 46
# time taken: 664.5156502723694
# [50,    50] loss: 6.417
# [50,   100] loss: 6.250
# [50,   150] loss: 6.464
# [50,   200] loss: 6.486
# [50,   250] loss: 6.540
# [50,   300] loss: 6.664
# [50,   350] loss: 6.700
# [50,   400] loss: 6.806
# [50,   450] loss: 6.837
# [50,   500] loss: 6.818
# Accuracy of the network on the test images: 42.24 %
# Best Accuracy of 43.22 at epoch 46
# time taken: 664.2771263122559
# [51,    50] loss: 6.436
# [51,   100] loss: 6.276
# [51,   150] loss: 6.425
# [51,   200] loss: 6.493
# [51,   250] loss: 6.564
# [51,   300] loss: 6.638
# [51,   350] loss: 6.682
# [51,   400] loss: 6.694
# [51,   450] loss: 6.806
# [51,   500] loss: 6.882
# Accuracy of the network on the test images: 41.50 %
# Best Accuracy of 43.22 at epoch 46
# time taken: 664.1787283420563
# [52,    50] loss: 6.379
# [52,   100] loss: 6.215
# [52,   150] loss: 6.356
# [52,   200] loss: 6.469
# [52,   250] loss: 6.500
# [52,   300] loss: 6.529
# [52,   350] loss: 6.666
# [52,   400] loss: 6.745
# [52,   450] loss: 6.802
# [52,   500] loss: 6.849
# Accuracy of the network on the test images: 43.20 %
# Best Accuracy of 43.22 at epoch 46
# time taken: 664.0660345554352
# [53,    50] loss: 6.317
# [53,   100] loss: 6.184
# [53,   150] loss: 6.338
# [53,   200] loss: 6.453
# [53,   250] loss: 6.453
# [53,   300] loss: 6.500
# [53,   350] loss: 6.504
# [53,   400] loss: 6.705
# [53,   450] loss: 6.761
# [53,   500] loss: 6.885
# Accuracy of the network on the test images: 43.02 %
# Best Accuracy of 43.22 at epoch 46
# time taken: 664.3170301914215
# [54,    50] loss: 6.370
# [54,   100] loss: 6.240
# [54,   150] loss: 6.260
# [54,   200] loss: 6.382
# [54,   250] loss: 6.563
# [54,   300] loss: 6.494
# [54,   350] loss: 6.500
# [54,   400] loss: 6.649
# [54,   450] loss: 6.637
# [54,   500] loss: 6.723
# Accuracy of the network on the test images: 43.68 %
# Best Accuracy of 43.68 at epoch 54
# time taken: 664.67720079422
# [55,    50] loss: 6.219
# [55,   100] loss: 6.275
# [55,   150] loss: 6.229
# [55,   200] loss: 6.404
# [55,   250] loss: 6.513
# [55,   300] loss: 6.582
# [55,   350] loss: 6.572
# [55,   400] loss: 6.639
# [55,   450] loss: 6.731
# [55,   500] loss: 6.716
# Accuracy of the network on the test images: 42.00 %
# Best Accuracy of 43.68 at epoch 54
# time taken: 664.3477339744568
# [56,    50] loss: 6.279
# [56,   100] loss: 6.269
# [56,   150] loss: 6.317
# [56,   200] loss: 6.361
# [56,   250] loss: 6.467
# [56,   300] loss: 6.514
# [56,   350] loss: 6.577
# [56,   400] loss: 6.553
# [56,   450] loss: 6.598
# [56,   500] loss: 6.694
# Accuracy of the network on the test images: 42.72 %
# Best Accuracy of 43.68 at epoch 54
# time taken: 664.197824716568
# [57,    50] loss: 6.204
# [57,   100] loss: 6.128
# [57,   150] loss: 6.176
# [57,   200] loss: 6.427
# [57,   250] loss: 6.387
# [57,   300] loss: 6.499
# [57,   350] loss: 6.483
# [57,   400] loss: 6.688
# [57,   450] loss: 6.632
# [57,   500] loss: 6.715
# Accuracy of the network on the test images: 43.40 %
# Best Accuracy of 43.68 at epoch 54
# time taken: 664.4099724292755
# [58,    50] loss: 6.266
# [58,   100] loss: 6.098
# [58,   150] loss: 6.213
# [58,   200] loss: 6.294
# [58,   250] loss: 6.372
# [58,   300] loss: 6.358
# [58,   350] loss: 6.483
# [58,   400] loss: 6.557
# [58,   450] loss: 6.649
# [58,   500] loss: 6.656
# Accuracy of the network on the test images: 44.46 %
# Best Accuracy of 44.46 at epoch 58
# time taken: 664.7196910381317
# [59,    50] loss: 6.212
# [59,   100] loss: 6.120
# [59,   150] loss: 6.252
# [59,   200] loss: 6.291
# [59,   250] loss: 6.379
# [59,   300] loss: 6.513
# [59,   350] loss: 6.428
# [59,   400] loss: 6.466
# [59,   450] loss: 6.551
# [59,   500] loss: 6.612
# Accuracy of the network on the test images: 42.74 %
# Best Accuracy of 44.46 at epoch 58
# time taken: 664.2668397426605
# [60,    50] loss: 6.155
# [60,   100] loss: 6.162
# [60,   150] loss: 6.256
# [60,   200] loss: 6.297
# [60,   250] loss: 6.348
# [60,   300] loss: 6.493
# [60,   350] loss: 6.507
# [60,   400] loss: 6.432
# [60,   450] loss: 6.534
# [60,   500] loss: 6.610
# Accuracy of the network on the test images: 42.68 %
# Best Accuracy of 44.46 at epoch 58
# time taken: 664.4685180187225
# [61,    50] loss: 6.152
# [61,   100] loss: 5.992
# [61,   150] loss: 6.200
# [61,   200] loss: 6.299
# [61,   250] loss: 6.368
# [61,   300] loss: 6.349
# [61,   350] loss: 6.444
# [61,   400] loss: 6.433
# [61,   450] loss: 6.591
# [61,   500] loss: 6.583
# Accuracy of the network on the test images: 44.42 %
# Best Accuracy of 44.46 at epoch 58
# time taken: 663.9674544334412
# [62,    50] loss: 6.185
# [62,   100] loss: 5.998
# [62,   150] loss: 6.124
# [62,   200] loss: 6.218
# [62,   250] loss: 6.345
# [62,   300] loss: 6.350
# [62,   350] loss: 6.554
# [62,   400] loss: 6.475
# [62,   450] loss: 6.552
# [62,   500] loss: 6.724
# Accuracy of the network on the test images: 44.18 %
# Best Accuracy of 44.46 at epoch 58
# time taken: 660.0033943653107
# [63,    50] loss: 6.073
# [63,   100] loss: 6.058
# [63,   150] loss: 6.185
# [63,   200] loss: 6.325
# [63,   250] loss: 6.284
# [63,   300] loss: 6.343
# [63,   350] loss: 6.288
# [63,   400] loss: 6.464
# [63,   450] loss: 6.586
# [63,   500] loss: 6.513
# Accuracy of the network on the test images: 43.40 %
# Best Accuracy of 44.46 at epoch 58
# time taken: 661.2861976623535
# [64,    50] loss: 6.098
# [64,   100] loss: 6.115
# [64,   150] loss: 6.148
# [64,   200] loss: 6.175
# [64,   250] loss: 6.270
# [64,   300] loss: 6.235
# [64,   350] loss: 6.411
# [64,   400] loss: 6.416
# [64,   450] loss: 6.553
# [64,   500] loss: 6.538
# Accuracy of the network on the test images: 44.12 %
# Best Accuracy of 44.46 at epoch 58
# time taken: 664.2790975570679
# [65,    50] loss: 6.127
# [65,   100] loss: 6.016
# [65,   150] loss: 6.087
# [65,   200] loss: 6.268
# [65,   250] loss: 6.239
# [65,   300] loss: 6.338
# [65,   350] loss: 6.359
# [65,   400] loss: 6.437
# [65,   450] loss: 6.470
# [65,   500] loss: 6.550
# Accuracy of the network on the test images: 42.40 %
# Best Accuracy of 44.46 at epoch 58
# time taken: 664.3967380523682
# [66,    50] loss: 6.142
# [66,   100] loss: 5.966
# [66,   150] loss: 6.015
# [66,   200] loss: 6.140
# [66,   250] loss: 6.337
# [66,   300] loss: 6.462
# [66,   350] loss: 6.407
# [66,   400] loss: 6.410
# [66,   450] loss: 6.447
# [66,   500] loss: 6.509
# Accuracy of the network on the test images: 42.54 %
# Best Accuracy of 44.46 at epoch 58
# time taken: 664.325192451477
# [67,    50] loss: 6.087
# [67,   100] loss: 6.003
# [67,   150] loss: 6.030
# [67,   200] loss: 6.206
# [67,   250] loss: 6.216
# [67,   300] loss: 6.269
# [67,   350] loss: 6.398
# [67,   400] loss: 6.334
# [67,   450] loss: 6.472
# [67,   500] loss: 6.569
# Accuracy of the network on the test images: 44.24 %
# Best Accuracy of 44.46 at epoch 58
# time taken: 664.820725440979
# [68,    50] loss: 6.058
# [68,   100] loss: 5.942
# [68,   150] loss: 6.031
# [68,   200] loss: 6.179
# [68,   250] loss: 6.298
# [68,   300] loss: 6.301
# [68,   350] loss: 6.438
# [68,   400] loss: 6.489
# [68,   450] loss: 6.458
# [68,   500] loss: 6.371
# Accuracy of the network on the test images: 43.38 %
# Best Accuracy of 44.46 at epoch 58
# time taken: 664.583878993988
# [69,    50] loss: 6.028
# [69,   100] loss: 5.994
# [69,   150] loss: 6.005
# [69,   200] loss: 6.117
# [69,   250] loss: 6.215
# [69,   300] loss: 6.311
# [69,   350] loss: 6.293
# [69,   400] loss: 6.333
# [69,   450] loss: 6.449
# [69,   500] loss: 6.509
# Accuracy of the network on the test images: 43.44 %
# Best Accuracy of 44.46 at epoch 58
# time taken: 664.5597884654999
# [70,    50] loss: 6.073
# [70,   100] loss: 5.975
# [70,   150] loss: 6.032
# [70,   200] loss: 6.014
# [70,   250] loss: 6.227
# [70,   300] loss: 6.237
# [70,   350] loss: 6.313
# [70,   400] loss: 6.379
# [70,   450] loss: 6.457
# [70,   500] loss: 6.455
# Accuracy of the network on the test images: 44.62 %
# Best Accuracy of 44.62 at epoch 70
# time taken: 664.6925337314606
# [71,    50] loss: 6.052
# [71,   100] loss: 6.022
# [71,   150] loss: 6.005
# [71,   200] loss: 6.137
# [71,   250] loss: 6.209
# [71,   300] loss: 6.236
# [71,   350] loss: 6.239
# [71,   400] loss: 6.321
# [71,   450] loss: 6.429
# [71,   500] loss: 6.437
# Accuracy of the network on the test images: 43.62 %
# Best Accuracy of 44.62 at epoch 70
# time taken: 664.5104849338531
# [72,    50] loss: 6.070
# [72,   100] loss: 5.955
# [72,   150] loss: 6.017
# [72,   200] loss: 6.176
# [72,   250] loss: 6.218
# [72,   300] loss: 6.167
# [72,   350] loss: 6.230
# [72,   400] loss: 6.278
# [72,   450] loss: 6.325
# [72,   500] loss: 6.404
# Accuracy of the network on the test images: 43.10 %
# Best Accuracy of 44.62 at epoch 70
# time taken: 664.6430065631866
# [73,    50] loss: 5.921
# [73,   100] loss: 5.859
# [73,   150] loss: 5.946
# [73,   200] loss: 6.067
# [73,   250] loss: 6.218
# [73,   300] loss: 6.331
# [73,   350] loss: 6.287
# [73,   400] loss: 6.375
# [73,   450] loss: 6.391
# [73,   500] loss: 6.460
# Accuracy of the network on the test images: 42.62 %
# Best Accuracy of 44.62 at epoch 70
# time taken: 664.632438659668
# [74,    50] loss: 6.054
# [74,   100] loss: 5.861
# [74,   150] loss: 6.094
# [74,   200] loss: 6.137
# [74,   250] loss: 6.120
# [74,   300] loss: 6.172
# [74,   350] loss: 6.178
# [74,   400] loss: 6.283
# [74,   450] loss: 6.312
# [74,   500] loss: 6.478
# Accuracy of the network on the test images: 43.86 %
# Best Accuracy of 44.62 at epoch 70
# time taken: 664.7330899238586
# [75,    50] loss: 5.995
# [75,   100] loss: 5.893
# [75,   150] loss: 5.975
# [75,   200] loss: 5.997
# [75,   250] loss: 6.186
# [75,   300] loss: 6.152
# [75,   350] loss: 6.241
# [75,   400] loss: 6.235
# [75,   450] loss: 6.363
# [75,   500] loss: 6.346
# Accuracy of the network on the test images: 43.54 %
# Best Accuracy of 44.62 at epoch 70
# time taken: 664.5141339302063
# [76,    50] loss: 5.975
# [76,   100] loss: 5.919
# [76,   150] loss: 5.871
# [76,   200] loss: 6.136
# [76,   250] loss: 6.156
# [76,   300] loss: 6.199
# [76,   350] loss: 6.241
# [76,   400] loss: 6.334
# [76,   450] loss: 6.353
# [76,   500] loss: 6.420
# Accuracy of the network on the test images: 44.50 %
# Best Accuracy of 44.62 at epoch 70
# time taken: 664.5455460548401
# [77,    50] loss: 6.050
# [77,   100] loss: 5.910
# [77,   150] loss: 6.030
# [77,   200] loss: 5.994
# [77,   250] loss: 6.125
# [77,   300] loss: 6.205
# [77,   350] loss: 6.150
# [77,   400] loss: 6.284
# [77,   450] loss: 6.272
# [77,   500] loss: 6.337
# Accuracy of the network on the test images: 43.52 %
# Best Accuracy of 44.62 at epoch 70
# time taken: 664.7217245101929
# [78,    50] loss: 5.921
# [78,   100] loss: 5.860
# [78,   150] loss: 5.913
# [78,   200] loss: 5.982
# [78,   250] loss: 6.123
# [78,   300] loss: 6.058
# [78,   350] loss: 6.292
# [78,   400] loss: 6.241
# [78,   450] loss: 6.413
# [78,   500] loss: 6.363
# Accuracy of the network on the test images: 43.76 %
# Best Accuracy of 44.62 at epoch 70
# time taken: 664.6683909893036
# [79,    50] loss: 5.947
# [79,   100] loss: 5.872
# [79,   150] loss: 5.894
# [79,   200] loss: 6.008
# [79,   250] loss: 6.092
# [79,   300] loss: 6.202
# [79,   350] loss: 6.193
# [79,   400] loss: 6.276
# [79,   450] loss: 6.266
# [79,   500] loss: 6.345
# Accuracy of the network on the test images: 44.66 %
# Best Accuracy of 44.66 at epoch 79
# time taken: 665.1502840518951
# [80,    50] loss: 5.949
# [80,   100] loss: 5.771
# [80,   150] loss: 5.915
# [80,   200] loss: 6.095
# [80,   250] loss: 6.079
# [80,   300] loss: 6.156
# [80,   350] loss: 6.209
# [80,   400] loss: 6.238
# [80,   450] loss: 6.269
# [80,   500] loss: 6.272
# Accuracy of the network on the test images: 43.62 %
# Best Accuracy of 44.66 at epoch 79
# time taken: 664.5984756946564
# [81,    50] loss: 5.951
# [81,   100] loss: 5.799
# [81,   150] loss: 5.853
# [81,   200] loss: 5.966
# [LOG] Successfully changed variable learning_rate.
# [81,   250] loss: 6.090
# [81,   300] loss: 6.107
# [81,   350] loss: 6.142
# [81,   400] loss: 6.247
# [81,   450] loss: 6.297
# [81,   500] loss: 6.271
# Accuracy of the network on the test images: 44.48 %
# Best Accuracy of 44.66 at epoch 79
# time taken: 664.7287445068359
# [82,    50] loss: 5.057
# [82,   100] loss: 4.611
# [82,   150] loss: 4.489
# [82,   200] loss: 4.385
# [82,   250] loss: 4.358
# [82,   300] loss: 4.307
# [82,   350] loss: 4.259
# [82,   400] loss: 4.268
# [82,   450] loss: 4.208
# [82,   500] loss: 4.178
# Accuracy of the network on the test images: 51.26 %
# Best Accuracy of 51.26 at epoch 82
# time taken: 659.646461725235
# [83,    50] loss: 4.066
# [83,   100] loss: 4.036
# [83,   150] loss: 3.959
# [83,   200] loss: 4.035
# [83,   250] loss: 3.983
# [83,   300] loss: 3.976
# [83,   350] loss: 3.959
# [83,   400] loss: 3.924
# [83,   450] loss: 3.907
# [83,   500] loss: 3.941
# Accuracy of the network on the test images: 52.04 %
# Best Accuracy of 52.04 at epoch 83
# time taken: 663.7162477970123
# [84,    50] loss: 3.845
# [84,   100] loss: 3.823
# [84,   150] loss: 3.813
# [84,   200] loss: 3.825
# [84,   250] loss: 3.792
# [84,   300] loss: 3.817
# [84,   350] loss: 3.782
# [84,   400] loss: 3.847
# [84,   450] loss: 3.808
# [84,   500] loss: 3.801
# Accuracy of the network on the test images: 52.14 %
# Best Accuracy of 52.14 at epoch 84
# time taken: 664.897855758667
# [85,    50] loss: 3.651
# [85,   100] loss: 3.714
# [85,   150] loss: 3.645
# [85,   200] loss: 3.687
# [85,   250] loss: 3.677
# [85,   300] loss: 3.685
# [85,   350] loss: 3.674
# [85,   400] loss: 3.684
# [85,   450] loss: 3.699
# [85,   500] loss: 3.697
# Accuracy of the network on the test images: 53.24 %
# Best Accuracy of 53.24 at epoch 85
# time taken: 664.6623792648315
# [86,    50] loss: 3.595
# [86,   100] loss: 3.567
# [86,   150] loss: 3.577
# [86,   200] loss: 3.572
# [86,   250] loss: 3.576
# [86,   300] loss: 3.632
# [86,   350] loss: 3.585
# [86,   400] loss: 3.601
# [86,   450] loss: 3.640
# [86,   500] loss: 3.617
# Accuracy of the network on the test images: 53.16 %
# Best Accuracy of 53.24 at epoch 85
# time taken: 663.1142563819885
# [87,    50] loss: 3.493
# [87,   100] loss: 3.564
# [87,   150] loss: 3.531
# [87,   200] loss: 3.519
# [87,   250] loss: 3.535
# [87,   300] loss: 3.515
# [87,   350] loss: 3.497
# [87,   400] loss: 3.571
# [87,   450] loss: 3.538
# [87,   500] loss: 3.548
# Accuracy of the network on the test images: 53.62 %
# Best Accuracy of 53.62 at epoch 87
# time taken: 664.422336101532
# [88,    50] loss: 3.437
# [88,   100] loss: 3.436
# [88,   150] loss: 3.404
# [88,   200] loss: 3.433
# [88,   250] loss: 3.432
# [88,   300] loss: 3.495
# [88,   350] loss: 3.456
# [88,   400] loss: 3.531
# [88,   450] loss: 3.529
# [88,   500] loss: 3.479
# Accuracy of the network on the test images: 53.74 %
# Best Accuracy of 53.74 at epoch 88
# time taken: 663.3162171840668
# [89,    50] loss: 3.342
# [89,   100] loss: 3.396
# [89,   150] loss: 3.415
# [89,   200] loss: 3.372
# [89,   250] loss: 3.398
# [89,   300] loss: 3.394
# [89,   350] loss: 3.438
# [89,   400] loss: 3.455
# [89,   450] loss: 3.460
# [89,   500] loss: 3.438
# Accuracy of the network on the test images: 53.86 %
# Best Accuracy of 53.86 at epoch 89
# time taken: 664.9717149734497
# [90,    50] loss: 3.347
# [90,   100] loss: 3.337
# [90,   150] loss: 3.340
# [90,   200] loss: 3.345
# [90,   250] loss: 3.409
# [90,   300] loss: 3.391
# [90,   350] loss: 3.368
# [90,   400] loss: 3.368
# [90,   450] loss: 3.375
# [90,   500] loss: 3.404
# Accuracy of the network on the test images: 53.58 %
# Best Accuracy of 53.86 at epoch 89
# time taken: 665.6831738948822
# [91,    50] loss: 3.213
# [91,   100] loss: 3.316
# [91,   150] loss: 3.327
# [91,   200] loss: 3.309
# [91,   250] loss: 3.332
# [91,   300] loss: 3.327
# [91,   350] loss: 3.335
# [91,   400] loss: 3.356
# [91,   450] loss: 3.355
# [91,   500] loss: 3.351
# Accuracy of the network on the test images: 53.54 %
# Best Accuracy of 53.86 at epoch 89
# time taken: 668.4019997119904
# [92,    50] loss: 3.282
# [92,   100] loss: 3.274
# [92,   150] loss: 3.264
# [92,   200] loss: 3.266
# [92,   250] loss: 3.262
# [92,   300] loss: 3.289
# [92,   350] loss: 3.292
# [92,   400] loss: 3.338
# [92,   450] loss: 3.310
# [92,   500] loss: 3.327
# Accuracy of the network on the test images: 54.38 %
# Best Accuracy of 54.38 at epoch 92
# time taken: 670.7643530368805
# [93,    50] loss: 3.219
# [93,   100] loss: 3.230
# [93,   150] loss: 3.204
# [93,   200] loss: 3.272
# [93,   250] loss: 3.236
# [93,   300] loss: 3.257
# [93,   350] loss: 3.317
# [93,   400] loss: 3.278
# [93,   450] loss: 3.283
# [93,   500] loss: 3.290
# Accuracy of the network on the test images: 54.04 %
# Best Accuracy of 54.38 at epoch 92
# time taken: 671.6462461948395
# [94,    50] loss: 3.237
# [94,   100] loss: 3.171
# [94,   150] loss: 3.215
# [94,   200] loss: 3.183
# [94,   250] loss: 3.200
# [94,   300] loss: 3.227
# [94,   350] loss: 3.243
# [94,   400] loss: 3.221
# [94,   450] loss: 3.251
# [94,   500] loss: 3.226
# Accuracy of the network on the test images: 53.92 %
# Best Accuracy of 54.38 at epoch 92
# time taken: 670.7504572868347
# [95,    50] loss: 3.149
# [95,   100] loss: 3.178
# [95,   150] loss: 3.166
# [95,   200] loss: 3.189
# [95,   250] loss: 3.198
# [95,   300] loss: 3.195
# [95,   350] loss: 3.214
# [95,   400] loss: 3.219
# [95,   450] loss: 3.216
# [95,   500] loss: 3.256
# Accuracy of the network on the test images: 54.10 %
# Best Accuracy of 54.38 at epoch 92
# time taken: 670.6436049938202
# [96,    50] loss: 3.086
# [96,   100] loss: 3.179
# [96,   150] loss: 3.133
# [96,   200] loss: 3.196
# [96,   250] loss: 3.137
# [96,   300] loss: 3.220
# [96,   350] loss: 3.181
# [96,   400] loss: 3.217
# [96,   450] loss: 3.159
# [96,   500] loss: 3.172
# Accuracy of the network on the test images: 54.10 %
# Best Accuracy of 54.38 at epoch 92
# time taken: 670.5332882404327
# [97,    50] loss: 3.120
# [97,   100] loss: 3.124
# [97,   150] loss: 3.098
# [97,   200] loss: 3.144
# [97,   250] loss: 3.119
# [97,   300] loss: 3.190
# [97,   350] loss: 3.132
# [97,   400] loss: 3.192
# [97,   450] loss: 3.166
# [97,   500] loss: 3.187
# Accuracy of the network on the test images: 54.72 %
# Best Accuracy of 54.72 at epoch 97
# time taken: 671.3673448562622
# [98,    50] loss: 3.092
# [98,   100] loss: 3.071
# [98,   150] loss: 3.081
# [98,   200] loss: 3.095
# [98,   250] loss: 3.172
# [98,   300] loss: 3.150
# [98,   350] loss: 3.138
# [98,   400] loss: 3.151
# [98,   450] loss: 3.123
# [98,   500] loss: 3.158
# Accuracy of the network on the test images: 54.62 %
# Best Accuracy of 54.72 at epoch 97
# time taken: 668.6105561256409
# [99,    50] loss: 3.062
# [99,   100] loss: 3.092
# [99,   150] loss: 3.106
# [99,   200] loss: 3.098
# [99,   250] loss: 3.057
# [99,   300] loss: 3.086
# [99,   350] loss: 3.112
# [99,   400] loss: 3.134
# [99,   450] loss: 3.142
# [99,   500] loss: 3.154
# Accuracy of the network on the test images: 54.62 %
# Best Accuracy of 54.72 at epoch 97
# time taken: 670.3910157680511
# [100,    50] loss: 3.034
# [100,   100] loss: 3.069
# [100,   150] loss: 3.082
# [100,   200] loss: 3.075
# [100,   250] loss: 3.061
# [100,   300] loss: 3.095
# [100,   350] loss: 3.104
# [100,   400] loss: 3.111
# [100,   450] loss: 3.119
# [100,   500] loss: 3.084
# Accuracy of the network on the test images: 53.82 %
# Best Accuracy of 54.72 at epoch 97
# time taken: 670.0035285949707
# [101,    50] loss: 3.041
# [101,   100] loss: 3.022
# [101,   150] loss: 3.049
# [101,   200] loss: 3.034
# [101,   250] loss: 3.077
# [101,   300] loss: 3.094
# [101,   350] loss: 3.088
# [101,   400] loss: 3.063
# [101,   450] loss: 3.120
# [101,   500] loss: 3.112
# Accuracy of the network on the test images: 54.34 %
# Best Accuracy of 54.72 at epoch 97
# time taken: 668.94003033638
# [102,    50] loss: 3.003
# [102,   100] loss: 3.026
# [102,   150] loss: 3.073
# [102,   200] loss: 3.018
# [102,   250] loss: 3.023
# [102,   300] loss: 3.074
# [102,   350] loss: 3.066
# [102,   400] loss: 3.055
# [102,   450] loss: 3.056
# [102,   500] loss: 3.080
# Accuracy of the network on the test images: 54.96 %
# Best Accuracy of 54.96 at epoch 102
# time taken: 669.5750336647034
# [103,    50] loss: 2.937
# [103,   100] loss: 2.981
# [103,   150] loss: 3.009
# [103,   200] loss: 3.039
# [103,   250] loss: 2.978
# [103,   300] loss: 3.041
# [103,   350] loss: 3.012
# [103,   400] loss: 3.043
# [103,   450] loss: 3.087
# [103,   500] loss: 3.047
# Accuracy of the network on the test images: 54.88 %
# Best Accuracy of 54.96 at epoch 102
# time taken: 669.5012879371643
# [104,    50] loss: 2.991
# [104,   100] loss: 2.961
# [104,   150] loss: 3.005
# [104,   200] loss: 2.983
# [104,   250] loss: 3.001
# [104,   300] loss: 3.041
# [104,   350] loss: 3.027
# [104,   400] loss: 3.004
# [104,   450] loss: 3.071
# [104,   500] loss: 3.047
# Accuracy of the network on the test images: 54.54 %
# Best Accuracy of 54.96 at epoch 102
# time taken: 670.584285736084
# [105,    50] loss: 2.942
# [105,   100] loss: 2.969
# [105,   150] loss: 2.991
# [105,   200] loss: 2.970
# [105,   250] loss: 3.000
# [105,   300] loss: 3.002
# [105,   350] loss: 3.073
# [105,   400] loss: 3.007
# [105,   450] loss: 3.058
# [105,   500] loss: 3.051
# Accuracy of the network on the test images: 55.24 %
# Best Accuracy of 55.24 at epoch 105
# time taken: 670.8012235164642
# [106,    50] loss: 2.942
# [106,   100] loss: 2.953
# [106,   150] loss: 2.945
# [106,   200] loss: 2.960
# [106,   250] loss: 2.986
# [106,   300] loss: 2.997
# [106,   350] loss: 2.978
# [106,   400] loss: 3.019
# [106,   450] loss: 3.047
# [106,   500] loss: 3.059
# Accuracy of the network on the test images: 54.76 %
# Best Accuracy of 55.24 at epoch 105
# time taken: 668.7211871147156
# [107,    50] loss: 2.939
# [107,   100] loss: 2.926
# [107,   150] loss: 2.952
# [107,   200] loss: 2.934
# [107,   250] loss: 2.962
# [107,   300] loss: 2.957
# [107,   350] loss: 3.003
# [107,   400] loss: 3.021
# [107,   450] loss: 3.007
# [107,   500] loss: 2.991
# Accuracy of the network on the test images: 55.26 %
# Best Accuracy of 55.26 at epoch 107
# time taken: 670.6824676990509
# [108,    50] loss: 2.911
# [108,   100] loss: 2.939
# [108,   150] loss: 2.930
# [108,   200] loss: 2.939
# [108,   250] loss: 2.954
# [108,   300] loss: 2.972
# [108,   350] loss: 2.958
# [108,   400] loss: 2.955
# [108,   450] loss: 2.968
# [108,   500] loss: 2.976
# Accuracy of the network on the test images: 55.18 %
# Best Accuracy of 55.26 at epoch 107
# time taken: 668.5019326210022
# [109,    50] loss: 2.902
# [109,   100] loss: 2.912
# [109,   150] loss: 2.895
# [109,   200] loss: 2.936
# [109,   250] loss: 2.946
# [109,   300] loss: 2.935
# [109,   350] loss: 2.963
# [109,   400] loss: 2.990
# [109,   450] loss: 2.985
# [109,   500] loss: 2.998
# Accuracy of the network on the test images: 55.12 %
# Best Accuracy of 55.26 at epoch 107
# time taken: 666.3175048828125
# [110,    50] loss: 2.886
# [110,   100] loss: 2.882
# [110,   150] loss: 2.906
# [110,   200] loss: 2.892
# [110,   250] loss: 2.926
# [110,   300] loss: 2.925
# [110,   350] loss: 2.927
# [110,   400] loss: 2.955
# [110,   450] loss: 2.955
# [110,   500] loss: 2.977
# Accuracy of the network on the test images: 55.12 %
# Best Accuracy of 55.26 at epoch 107
# time taken: 664.8754937648773
# [111,    50] loss: 2.866
# [111,   100] loss: 2.876
# [111,   150] loss: 2.900
# [111,   200] loss: 2.886
# [111,   250] loss: 2.932
# [111,   300] loss: 2.894
# [111,   350] loss: 2.909
# [111,   400] loss: 2.915
# [111,   450] loss: 2.958
# [111,   500] loss: 2.953
# Accuracy of the network on the test images: 54.94 %
# Best Accuracy of 55.26 at epoch 107
# time taken: 664.9639227390289
# [112,    50] loss: 2.828
# [112,   100] loss: 2.861
# [112,   150] loss: 2.897
# [112,   200] loss: 2.876
# [112,   250] loss: 2.878
# [112,   300] loss: 2.921
# [112,   350] loss: 2.914
# [112,   400] loss: 2.882
# [112,   450] loss: 2.964
# [112,   500] loss: 2.945
# Accuracy of the network on the test images: 54.62 %
# Best Accuracy of 55.26 at epoch 107
# time taken: 664.6920928955078
# [113,    50] loss: 2.863
# [113,   100] loss: 2.836
# [113,   150] loss: 2.854
# [113,   200] loss: 2.897
# [113,   250] loss: 2.878
# [113,   300] loss: 2.874
# [113,   350] loss: 2.905
# [113,   400] loss: 2.909
# [113,   450] loss: 2.928
# [113,   500] loss: 2.899
# Accuracy of the network on the test images: 54.92 %
# Best Accuracy of 55.26 at epoch 107
# time taken: 664.3517124652863
# [114,    50] loss: 2.817
# [114,   100] loss: 2.874
# [114,   150] loss: 2.886
# [114,   200] loss: 2.855
# [114,   250] loss: 2.889
# [114,   300] loss: 2.889
# [114,   350] loss: 2.891
# [114,   400] loss: 2.913
# [114,   450] loss: 2.896
# [114,   500] loss: 2.912
# Accuracy of the network on the test images: 55.38 %
# Best Accuracy of 55.38 at epoch 114
# time taken: 664.9922113418579
# [115,    50] loss: 2.802
# [115,   100] loss: 2.829
# [115,   150] loss: 2.863
# [115,   200] loss: 2.860
# [115,   250] loss: 2.838
# [115,   300] loss: 2.894
# [115,   350] loss: 2.871
# [115,   400] loss: 2.918
# [115,   450] loss: 2.895
# [115,   500] loss: 2.931
# Accuracy of the network on the test images: 55.62 %
# Best Accuracy of 55.62 at epoch 115
# time taken: 664.8702352046967
# [116,    50] loss: 2.805
# [116,   100] loss: 2.840
# [116,   150] loss: 2.809
# [116,   200] loss: 2.840
# [116,   250] loss: 2.853
# [116,   300] loss: 2.921
# [116,   350] loss: 2.892
# [116,   400] loss: 2.877
# [116,   450] loss: 2.876
# [116,   500] loss: 2.896
# Accuracy of the network on the test images: 55.60 %
# Best Accuracy of 55.62 at epoch 115
# time taken: 664.6256408691406
# [117,    50] loss: 2.785
# [117,   100] loss: 2.848
# [117,   150] loss: 2.815
# [117,   200] loss: 2.865
# [117,   250] loss: 2.876
# [117,   300] loss: 2.844
# [117,   350] loss: 2.882
# [117,   400] loss: 2.879
# [117,   450] loss: 2.886
# [117,   500] loss: 2.888
# Accuracy of the network on the test images: 54.70 %
# Best Accuracy of 55.62 at epoch 115
# time taken: 664.4155631065369
# [118,    50] loss: 2.787
# [118,   100] loss: 2.786
# [118,   150] loss: 2.813
# [118,   200] loss: 2.814
# [118,   250] loss: 2.841
# [118,   300] loss: 2.843
# [118,   350] loss: 2.869
# [118,   400] loss: 2.870
# [118,   450] loss: 2.872
# [118,   500] loss: 2.914
# Accuracy of the network on the test images: 55.62 %
# Best Accuracy of 55.62 at epoch 115
# time taken: 664.0820002555847
# [119,    50] loss: 2.799
# [119,   100] loss: 2.774
# [119,   150] loss: 2.763
# [119,   200] loss: 2.796
# [119,   250] loss: 2.837
# [119,   300] loss: 2.851
# [119,   350] loss: 2.836
# [119,   400] loss: 2.821
# [119,   450] loss: 2.872
# [119,   500] loss: 2.883
# Accuracy of the network on the test images: 55.40 %
# Best Accuracy of 55.62 at epoch 115
# time taken: 664.4677736759186
# [120,    50] loss: 2.805
# [120,   100] loss: 2.782
# [120,   150] loss: 2.808
# [120,   200] loss: 2.773
# [120,   250] loss: 2.810
# [120,   300] loss: 2.857
# [120,   350] loss: 2.858
# [120,   400] loss: 2.827
# [120,   450] loss: 2.824
# [120,   500] loss: 2.932
# Accuracy of the network on the test images: 55.66 %
# Best Accuracy of 55.66 at epoch 120
# time taken: 664.7412574291229
# [121,    50] loss: 2.776
# [121,   100] loss: 2.772
# [121,   150] loss: 2.795
# [121,   200] loss: 2.781
# [121,   250] loss: 2.798
# [121,   300] loss: 2.810
# [121,   350] loss: 2.823
# [121,   400] loss: 2.862
# [121,   450] loss: 2.868
# [121,   500] loss: 2.842
# Accuracy of the network on the test images: 54.98 %
# Best Accuracy of 55.66 at epoch 120
# time taken: 664.661673784256
# [122,    50] loss: 2.744
# [122,   100] loss: 2.779
# [122,   150] loss: 2.780
# [122,   200] loss: 2.806
# [122,   250] loss: 2.793
# [122,   300] loss: 2.823
# [122,   350] loss: 2.838
# [122,   400] loss: 2.805
# [122,   450] loss: 2.837
# [122,   500] loss: 2.834
# Accuracy of the network on the test images: 55.12 %
# Best Accuracy of 55.66 at epoch 120
# time taken: 664.4097182750702
# [123,    50] loss: 2.807
# [123,   100] loss: 2.774
# [123,   150] loss: 2.766
# [123,   200] loss: 2.787
# [123,   250] loss: 2.815
# [123,   300] loss: 2.808
# [123,   350] loss: 2.803
# [123,   400] loss: 2.815
# [123,   450] loss: 2.799
# [123,   500] loss: 2.821
# Accuracy of the network on the test images: 55.48 %
# Best Accuracy of 55.66 at epoch 120
# time taken: 664.8753323554993
# [124,    50] loss: 2.718
# [124,   100] loss: 2.767
# [124,   150] loss: 2.732
# [124,   200] loss: 2.768
# [124,   250] loss: 2.791
# [124,   300] loss: 2.796
# [124,   350] loss: 2.835
# [124,   400] loss: 2.809
# [124,   450] loss: 2.843
# [124,   500] loss: 2.829
# Accuracy of the network on the test images: 55.18 %
# Best Accuracy of 55.66 at epoch 120
# time taken: 664.7336301803589
# [125,    50] loss: 2.720
# [125,   100] loss: 2.748
# [125,   150] loss: 2.743
# [125,   200] loss: 2.770
# [125,   250] loss: 2.788
# [125,   300] loss: 2.810
# [125,   350] loss: 2.775
# [125,   400] loss: 2.806
# [125,   450] loss: 2.821
# [125,   500] loss: 2.826
# Accuracy of the network on the test images: 55.80 %
# Best Accuracy of 55.8 at epoch 125
# time taken: 665.2306046485901
# [126,    50] loss: 2.722
# [126,   100] loss: 2.727
# [126,   150] loss: 2.711
# [126,   200] loss: 2.734
# [126,   250] loss: 2.754
# [126,   300] loss: 2.790
# [126,   350] loss: 2.776
# [126,   400] loss: 2.792
# [126,   450] loss: 2.833
# [126,   500] loss: 2.842
# Accuracy of the network on the test images: 56.12 %
# Best Accuracy of 56.12 at epoch 126
# time taken: 665.8123667240143
# [127,    50] loss: 2.729
# [127,   100] loss: 2.729
# [127,   150] loss: 2.731
# [127,   200] loss: 2.747
# [127,   250] loss: 2.771
# [127,   300] loss: 2.737
# [127,   350] loss: 2.757
# [127,   400] loss: 2.777
# [127,   450] loss: 2.832
# [127,   500] loss: 2.820
# Accuracy of the network on the test images: 55.94 %
# Best Accuracy of 56.12 at epoch 126
# time taken: 665.3088517189026
# [128,    50] loss: 2.714
# [128,   100] loss: 2.714
# [128,   150] loss: 2.753
# [128,   200] loss: 2.773
# [128,   250] loss: 2.752
# [128,   300] loss: 2.764
# [128,   350] loss: 2.806
# [128,   400] loss: 2.773
# [128,   450] loss: 2.775
# [128,   500] loss: 2.807
# Accuracy of the network on the test images: 55.40 %
# Best Accuracy of 56.12 at epoch 126
# time taken: 665.3838665485382
# [129,    50] loss: 2.712
# [129,   100] loss: 2.665
# [129,   150] loss: 2.739
# [129,   200] loss: 2.721
# [129,   250] loss: 2.755
# [129,   300] loss: 2.752
# [129,   350] loss: 2.788
# [129,   400] loss: 2.757
# [129,   450] loss: 2.778
# [129,   500] loss: 2.841
# Accuracy of the network on the test images: 55.34 %
# Best Accuracy of 56.12 at epoch 126
# time taken: 665.6255719661713
# [130,    50] loss: 2.688
# [130,   100] loss: 2.687
# [130,   150] loss: 2.692
# [130,   200] loss: 2.729
# [130,   250] loss: 2.730
# [130,   300] loss: 2.786
# [130,   350] loss: 2.756
# [130,   400] loss: 2.780
# [130,   450] loss: 2.800
# [130,   500] loss: 2.787
# Accuracy of the network on the test images: 55.74 %
# Best Accuracy of 56.12 at epoch 126
# time taken: 665.6029713153839
# [131,    50] loss: 2.689
# [131,   100] loss: 2.695
# [131,   150] loss: 2.716
# [131,   200] loss: 2.723
# [131,   250] loss: 2.725
# [131,   300] loss: 2.754
# [131,   350] loss: 2.803
# [131,   400] loss: 2.757
# [131,   450] loss: 2.762
# [131,   500] loss: 2.745
# Accuracy of the network on the test images: 56.24 %
# Best Accuracy of 56.24 at epoch 131
# time taken: 665.7004117965698
# [132,    50] loss: 2.709
# [132,   100] loss: 2.692
# [132,   150] loss: 2.689
# [132,   200] loss: 2.705
# [132,   250] loss: 2.710
# [132,   300] loss: 2.763
# [132,   350] loss: 2.757
# [132,   400] loss: 2.761
# [132,   450] loss: 2.763
# [132,   500] loss: 2.790
# Accuracy of the network on the test images: 55.56 %
# Best Accuracy of 56.24 at epoch 131
# time taken: 665.3966152667999
# [133,    50] loss: 2.683
# [133,   100] loss: 2.685
# [133,   150] loss: 2.702
# [133,   200] loss: 2.724
# [133,   250] loss: 2.737
# [133,   300] loss: 2.696
# [133,   350] loss: 2.735
# [133,   400] loss: 2.740
# [133,   450] loss: 2.776
# [133,   500] loss: 2.783
# Accuracy of the network on the test images: 55.88 %
# Best Accuracy of 56.24 at epoch 131
# time taken: 665.6239366531372
# [134,    50] loss: 2.703
# ...
# [147,   500] loss: 2.686
# Accuracy of the network on the test images: 56.10 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 665.006281375885
# [148,    50] loss: 2.620
# [148,   100] loss: 2.603
# [148,   150] loss: 2.626
# [148,   200] loss: 2.639
# [148,   250] loss: 2.650
# [148,   300] loss: 2.621
# [148,   350] loss: 2.672
# [148,   400] loss: 2.673
# [148,   450] loss: 2.627
# [148,   500] loss: 2.699
# Accuracy of the network on the test images: 55.94 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 665.3137006759644
# [149,    50] loss: 2.583
# [149,   100] loss: 2.601
# [149,   150] loss: 2.625
# [149,   200] loss: 2.649
# [149,   250] loss: 2.630
# [149,   300] loss: 2.661
# [149,   350] loss: 2.705
# [149,   400] loss: 2.667
# [149,   450] loss: 2.689
# [149,   500] loss: 2.647
# Accuracy of the network on the test images: 55.52 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 665.1109964847565
# [150,    50] loss: 2.580
# [150,   100] loss: 2.590
# [150,   150] loss: 2.615
# [150,   200] loss: 2.576
# [150,   250] loss: 2.643
# [150,   300] loss: 2.658
# [150,   350] loss: 2.628
# [150,   400] loss: 2.685
# [150,   450] loss: 2.677
# [150,   500] loss: 2.700
# Accuracy of the network on the test images: 55.94 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 665.1740701198578
# [151,    50] loss: 2.602
# [151,   100] loss: 2.582
# [151,   150] loss: 2.623
# [151,   200] loss: 2.609
# [151,   250] loss: 2.628
# [151,   300] loss: 2.614
# [151,   350] loss: 2.646
# [151,   400] loss: 2.670
# [151,   450] loss: 2.684
# [151,   500] loss: 2.694
# Accuracy of the network on the test images: 55.68 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 665.1879596710205
# [152,    50] loss: 2.583
# [152,   100] loss: 2.562
# [152,   150] loss: 2.608
# [152,   200] loss: 2.606
# [152,   250] loss: 2.628
# [152,   300] loss: 2.671
# [152,   350] loss: 2.670
# [152,   400] loss: 2.638
# [152,   450] loss: 2.658
# [152,   500] loss: 2.652
# Accuracy of the network on the test images: 55.62 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 665.0899622440338
# [153,    50] loss: 2.570
# [153,   100] loss: 2.578
# [153,   150] loss: 2.605
# [153,   200] loss: 2.612
# [153,   250] loss: 2.624
# [153,   300] loss: 2.641
# [153,   350] loss: 2.643
# [153,   400] loss: 2.612
# [153,   450] loss: 2.663
# [153,   500] loss: 2.685
# Accuracy of the network on the test images: 56.22 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 664.9344692230225
# [154,    50] loss: 2.557
# [154,   100] loss: 2.597
# [154,   150] loss: 2.603
# [154,   200] loss: 2.624
# [154,   250] loss: 2.634
# [154,   300] loss: 2.647
# [154,   350] loss: 2.652
# [154,   400] loss: 2.615
# [154,   450] loss: 2.662
# [154,   500] loss: 2.656
# Accuracy of the network on the test images: 55.82 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 664.9933123588562
# [155,    50] loss: 2.588
# [155,   100] loss: 2.595
# [155,   150] loss: 2.598
# [155,   200] loss: 2.613
# [155,   250] loss: 2.604
# [155,   300] loss: 2.612
# [155,   350] loss: 2.641
# [155,   400] loss: 2.650
# [155,   450] loss: 2.615
# [155,   500] loss: 2.628
# Accuracy of the network on the test images: 55.94 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 665.0192685127258
# [156,    50] loss: 2.577
# [156,   100] loss: 2.529
# [156,   150] loss: 2.589
# [156,   200] loss: 2.581
# [156,   250] loss: 2.604
# [156,   300] loss: 2.608
# [156,   350] loss: 2.629
# [156,   400] loss: 2.652
# [156,   450] loss: 2.663
# [156,   500] loss: 2.653
# Accuracy of the network on the test images: 56.12 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 664.9671154022217
# [157,    50] loss: 2.578
# [157,   100] loss: 2.564
# [157,   150] loss: 2.590
# [157,   200] loss: 2.607
# [157,   250] loss: 2.584
# [157,   300] loss: 2.605
# [157,   350] loss: 2.638
# [157,   400] loss: 2.603
# [157,   450] loss: 2.654
# [157,   500] loss: 2.640
# Accuracy of the network on the test images: 55.80 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 665.055558681488
# [158,    50] loss: 2.539
# [158,   100] loss: 2.569
# [158,   150] loss: 2.579
# [158,   200] loss: 2.571
# [158,   250] loss: 2.613
# [158,   300] loss: 2.623
# [158,   350] loss: 2.607
# [158,   400] loss: 2.607
# [158,   450] loss: 2.666
# [158,   500] loss: 2.651
# Accuracy of the network on the test images: 55.88 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 665.200838804245
# [159,    50] loss: 2.567
# [159,   100] loss: 2.524
# [159,   150] loss: 2.555
# [159,   200] loss: 2.579
# [159,   250] loss: 2.602
# [159,   300] loss: 2.583
# [159,   350] loss: 2.604
# [159,   400] loss: 2.636
# [159,   450] loss: 2.609
# [159,   500] loss: 2.649
# Accuracy of the network on the test images: 56.30 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 664.791234254837
# [160,    50] loss: 2.565
# [160,   100] loss: 2.530
# [160,   150] loss: 2.610
# [160,   200] loss: 2.564
# [160,   250] loss: 2.580
# [160,   300] loss: 2.625
# [160,   350] loss: 2.641
# [160,   400] loss: 2.617
# [160,   450] loss: 2.638
# [160,   500] loss: 2.613
# Accuracy of the network on the test images: 56.06 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 665.2115385532379
# [161,    50] loss: 2.576
# [161,   100] loss: 2.544
# [161,   150] loss: 2.566
# [161,   200] loss: 2.584
# [161,   250] loss: 2.589
# [161,   300] loss: 2.596
# [161,   350] loss: 2.601
# [161,   400] loss: 2.609
# [161,   450] loss: 2.602
# [161,   500] loss: 2.647
# Accuracy of the network on the test images: 56.32 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 665.2492983341217
# [162,    50] loss: 2.566
# [162,   100] loss: 2.548
# [162,   150] loss: 2.558
# [162,   200] loss: 2.618
# [162,   250] loss: 2.564
# [162,   300] loss: 2.610
# [162,   350] loss: 2.604
# [162,   400] loss: 2.595
# [162,   450] loss: 2.614
# [162,   500] loss: 2.630
# Accuracy of the network on the test images: 56.02 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 665.397932767868
# [163,    50] loss: 2.548
# [163,   100] loss: 2.532
# [163,   150] loss: 2.541
# [163,   200] loss: 2.583
# [163,   250] loss: 2.574
# [163,   300] loss: 2.614
# [163,   350] loss: 2.605
# [163,   400] loss: 2.598
# [163,   450] loss: 2.632
# [163,   500] loss: 2.580
# Accuracy of the network on the test images: 56.26 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 664.8343439102173
# [164,    50] loss: 2.563
# [164,   100] loss: 2.572
# [164,   150] loss: 2.576
# [164,   200] loss: 2.557
# [164,   250] loss: 2.586
# [164,   300] loss: 2.591
# [164,   350] loss: 2.571
# [164,   400] loss: 2.584
# [164,   450] loss: 2.630
# [164,   500] loss: 2.604
# Accuracy of the network on the test images: 55.96 %
# Best Accuracy of 56.52 at epoch 136
# time taken: 664.6174473762512
# [165,    50] loss: 2.539
# [165,   100] loss: 2.512
# [165,   150] loss: 2.529
# [165,   200] loss: 2.579
# [165,   250] loss: 2.576
# [165,   300] loss: 2.596
# [165,   350] loss: 2.591
# [165,   400] loss: 2.592
# [165,   450] loss: 2.620
# [165,   500] loss: 2.608
# Accuracy of the network on the test images: 56.54 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 664.7304046154022
# [166,    50] loss: 2.563
# [166,   100] loss: 2.518
# [166,   150] loss: 2.543
# [166,   200] loss: 2.574
# [166,   250] loss: 2.580
# [166,   300] loss: 2.571
# [166,   350] loss: 2.571
# [166,   400] loss: 2.604
# [166,   450] loss: 2.582
# [166,   500] loss: 2.638
# Accuracy of the network on the test images: 56.40 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 664.7298383712769
# [167,    50] loss: 2.544
# [167,   100] loss: 2.544
# [167,   150] loss: 2.553
# [167,   200] loss: 2.538
# [167,   250] loss: 2.565
# [167,   300] loss: 2.559
# [167,   350] loss: 2.587
# [167,   400] loss: 2.594
# [167,   450] loss: 2.598
# [167,   500] loss: 2.624
# Accuracy of the network on the test images: 56.28 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 664.6720750331879
# [168,    50] loss: 2.535
# [168,   100] loss: 2.529
# [168,   150] loss: 2.520
# [168,   200] loss: 2.540
# [168,   250] loss: 2.564
# [168,   300] loss: 2.587
# [168,   350] loss: 2.584
# [168,   400] loss: 2.598
# [168,   450] loss: 2.614
# [168,   500] loss: 2.588
# Accuracy of the network on the test images: 55.78 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 664.7343809604645
# [169,    50] loss: 2.553
# [169,   100] loss: 2.507
# [169,   150] loss: 2.526
# [169,   200] loss: 2.547
# [169,   250] loss: 2.562
# [169,   300] loss: 2.554
# [169,   350] loss: 2.549
# [169,   400] loss: 2.601
# [169,   450] loss: 2.620
# [169,   500] loss: 2.628
# Accuracy of the network on the test images: 56.12 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 664.5218243598938
# [170,    50] loss: 2.511
# [170,   100] loss: 2.530
# [170,   150] loss: 2.515
# [170,   200] loss: 2.526
# [170,   250] loss: 2.576
# [170,   300] loss: 2.558
# [170,   350] loss: 2.582
# [170,   400] loss: 2.584
# [170,   450] loss: 2.613
# [170,   500] loss: 2.590
# Accuracy of the network on the test images: 55.52 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 664.4611043930054
# [171,    50] loss: 2.520
# [171,   100] loss: 2.527
# [171,   150] loss: 2.530
# [171,   200] loss: 2.523
# [171,   250] loss: 2.550
# [171,   300] loss: 2.572
# [171,   350] loss: 2.592
# [171,   400] loss: 2.564
# [171,   450] loss: 2.588
# [171,   500] loss: 2.637
# Accuracy of the network on the test images: 56.50 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 664.4445397853851
# [172,    50] loss: 2.535
# [172,   100] loss: 2.513
# [172,   150] loss: 2.561
# [172,   200] loss: 2.536
# [172,   250] loss: 2.541
# [172,   300] loss: 2.596
# [172,   350] loss: 2.567
# [172,   400] loss: 2.575
# [172,   450] loss: 2.557
# [172,   500] loss: 2.561
# Accuracy of the network on the test images: 56.20 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 664.7705957889557
# [173,    50] loss: 2.524
# [173,   100] loss: 2.503
# [173,   150] loss: 2.528
# [173,   200] loss: 2.546
# [173,   250] loss: 2.559
# [173,   300] loss: 2.550
# [173,   350] loss: 2.560
# [173,   400] loss: 2.568
# [173,   450] loss: 2.588
# [173,   500] loss: 2.587
# Accuracy of the network on the test images: 55.80 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 664.281078338623
# [174,    50] loss: 2.518
# [174,   100] loss: 2.483
# [174,   150] loss: 2.511
# [174,   200] loss: 2.548
# [174,   250] loss: 2.549
# [174,   300] loss: 2.562
# [174,   350] loss: 2.553
# [174,   400] loss: 2.586
# [174,   450] loss: 2.595
# [174,   500] loss: 2.636
# Accuracy of the network on the test images: 56.30 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 664.3958189487457
# [175,    50] loss: 2.496
# [175,   100] loss: 2.536
# [175,   150] loss: 2.491
# [175,   200] loss: 2.518
# [175,   250] loss: 2.545
# [175,   300] loss: 2.582
# [175,   350] loss: 2.585
# [175,   400] loss: 2.539
# [175,   450] loss: 2.595
# [175,   500] loss: 2.606
# Accuracy of the network on the test images: 55.86 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 664.3951621055603
# [176,    50] loss: 2.544
# [176,   100] loss: 2.513
# [176,   150] loss: 2.518
# [176,   200] loss: 2.539
# [176,   250] loss: 2.558
# [176,   300] loss: 2.541
# [176,   350] loss: 2.557
# [176,   400] loss: 2.593
# [176,   450] loss: 2.599
# [176,   500] loss: 2.573
# Accuracy of the network on the test images: 55.96 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 661.4281480312347
# [177,    50] loss: 2.491
# [177,   100] loss: 2.498
# [177,   150] loss: 2.515
# [177,   200] loss: 2.554
# [177,   250] loss: 2.558
# [177,   300] loss: 2.523
# [177,   350] loss: 2.561
# [177,   400] loss: 2.591
# [177,   450] loss: 2.598
# [177,   500] loss: 2.572
# Accuracy of the network on the test images: 56.18 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 660.8748474121094
# [178,    50] loss: 2.513
# [178,   100] loss: 2.506
# [178,   150] loss: 2.528
# [178,   200] loss: 2.517
# [178,   250] loss: 2.541
# [178,   300] loss: 2.571
# [178,   350] loss: 2.544
# [178,   400] loss: 2.579
# [178,   450] loss: 2.553
# [178,   500] loss: 2.553
# Accuracy of the network on the test images: 56.22 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 659.9465832710266
# [179,    50] loss: 2.497
# [179,   100] loss: 2.473
# [179,   150] loss: 2.526
# [179,   200] loss: 2.537
# [179,   250] loss: 2.530
# [179,   300] loss: 2.512
# [179,   350] loss: 2.557
# [179,   400] loss: 2.546
# [179,   450] loss: 2.600
# [179,   500] loss: 2.563
# Accuracy of the network on the test images: 56.30 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 660.4578318595886
# [180,    50] loss: 2.497
# [180,   100] loss: 2.475
# [180,   150] loss: 2.503
# [180,   200] loss: 2.532
# [180,   250] loss: 2.524
# [180,   300] loss: 2.565
# [180,   350] loss: 2.517
# [180,   400] loss: 2.579
# [180,   450] loss: 2.590
# [180,   500] loss: 2.566
# Accuracy of the network on the test images: 55.98 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 663.9747858047485
# [181,    50] loss: 2.511
# [181,   100] loss: 2.490
# [181,   150] loss: 2.496
# [181,   200] loss: 2.542
# [181,   250] loss: 2.496
# [181,   300] loss: 2.536
# [181,   350] loss: 2.545
# [181,   400] loss: 2.567
# [181,   450] loss: 2.573
# [181,   500] loss: 2.555
# Accuracy of the network on the test images: 56.14 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 663.6248986721039
# [182,    50] loss: 2.546
# [182,   100] loss: 2.466
# [182,   150] loss: 2.504
# [182,   200] loss: 2.534
# [182,   250] loss: 2.514
# [182,   300] loss: 2.545
# [182,   350] loss: 2.558
# [182,   400] loss: 2.519
# [182,   450] loss: 2.581
# [182,   500] loss: 2.576
# Accuracy of the network on the test images: 56.08 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 663.8703579902649
# [183,    50] loss: 2.517
# [183,   100] loss: 2.461
# [183,   150] loss: 2.503
# [183,   200] loss: 2.501
# [183,   250] loss: 2.546
# [183,   300] loss: 2.550
# [183,   350] loss: 2.525
# [183,   400] loss: 2.542
# [183,   450] loss: 2.553
# [183,   500] loss: 2.573
# Accuracy of the network on the test images: 56.50 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 663.7101490497589
# [184,    50] loss: 2.488
# [184,   100] loss: 2.494
# [184,   150] loss: 2.509
# [184,   200] loss: 2.508
# [184,   250] loss: 2.510
# [184,   300] loss: 2.522
# [184,   350] loss: 2.561
# [184,   400] loss: 2.542
# [184,   450] loss: 2.549
# [184,   500] loss: 2.576
# Accuracy of the network on the test images: 55.86 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 663.8755629062653
# [185,    50] loss: 2.520
# [185,   100] loss: 2.502
# [185,   150] loss: 2.526
# [185,   200] loss: 2.503
# [185,   250] loss: 2.507
# [185,   300] loss: 2.509
# [185,   350] loss: 2.526
# [185,   400] loss: 2.562
# [185,   450] loss: 2.552
# [185,   500] loss: 2.581
# Accuracy of the network on the test images: 56.44 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 663.6793584823608
# [186,    50] loss: 2.514
# [186,   100] loss: 2.457
# [186,   150] loss: 2.512
# [186,   200] loss: 2.480
# [186,   250] loss: 2.522
# [186,   300] loss: 2.503
# [186,   350] loss: 2.524
# [186,   400] loss: 2.568
# [186,   450] loss: 2.543
# [186,   500] loss: 2.565
# Accuracy of the network on the test images: 56.10 %
# Best Accuracy of 56.54 at epoch 165
# time taken: 666.0759902000427
# [187,    50] loss: 2.487
# [187,   100] loss: 2.470
# [187,   150] loss: 2.512
# [187,   200] loss: 2.538
# [187,   250] loss: 2.505
# [187,   300] loss: 2.494
# [187,   350] loss: 2.534
# [187,   400] loss: 2.566
# [187,   450] loss: 2.515
# [187,   500] loss: 2.585
# Accuracy of the network on the test images: 56.58 %
# Best Accuracy of 56.58 at epoch 187
# time taken: 665.4507622718811
# [188,    50] loss: 2.498
# [188,   100] loss: 2.465
# [188,   150] loss: 2.464
# [188,   200] loss: 2.512
# [188,   250] loss: 2.504
# [188,   300] loss: 2.537
# [188,   350] loss: 2.526
# [188,   400] loss: 2.527
# [188,   450] loss: 2.543
# [188,   500] loss: 2.587
# Accuracy of the network on the test images: 56.54 %
# Best Accuracy of 56.58 at epoch 187
# time taken: 663.8143844604492
# [189,    50] loss: 2.490
# [189,   100] loss: 2.463
# [189,   150] loss: 2.472
# [189,   200] loss: 2.510
# [189,   250] loss: 2.513
# [189,   300] loss: 2.522
# Traceback (most recent call last):
#   File "/home/shariff/anaconda3/lib/python3.9/multiprocessing/queues.py", line 251, in _feed
#     send_bytes(obj)
#   File "/home/shariff/anaconda3/lib/python3.9/multiprocessing/connection.py", line 205, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/shariff/anaconda3/lib/python3.9/multiprocessing/connection.py", line 416, in _send_bytes
#     self._send(header + buf)
#   File "/home/shariff/anaconda3/lib/python3.9/multiprocessing/connection.py", line 373, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#
# KeyboardInterrupt

# %%
# criterion = nn.KLDivLoss(reduction="batchmean")

# %%
# output_log = F.log_softmax(output, dim=1)

# %%
# criterion(output, one_hot_labels)
